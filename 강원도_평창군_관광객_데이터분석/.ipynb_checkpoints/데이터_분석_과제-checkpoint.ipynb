# %%
file = "./data.csv"
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

data = pd.read_csv(file, encoding='cp949')
data.head()
# Out:
#           관광지 유_무료 내국인_외국인    연도      1월      2월      3월      4월      5월  \
# 0  국립두타산자연휴양림   유료     내국인  2010   2,831   1,497     770     894   2,600
# 1  국립평창청소년수련원   유료     내국인  2010   3,325   3,223  13,914  21,000  18,763
# 2    대관령 양떼목장   유료     내국인  2010  29,447  15,370   5,511  27,198  65,699
# 3       무이예술관   유료     내국인  2010     428     449     338     786   1,887
# 4     삼양대관령목장   유료     내국인  2010  21,170  12,984   5,660  25,293  65,600
#
#        6월      7월      8월      9월     10월     11월    12월     데이터기준일자
# 0   2,763   6,024   8,578   3,128   3,383   1,595  1,920  2022-01-05
# 1  20,125  18,442  17,518  11,938  21,221  10,471  9,354  2022-01-05
# 2  33,472  48,096  69,116  28,349  49,100  24,085  1,929  2022-01-05
# 3     789   2,512   5,095   2,435   1,123     603    376  2022-01-05
# 4  31,417  51,794  86,598  33,614  57,036  22,101  1,677  2022-01-05

# %%
for i in range(4, 16):
    data.iloc[:,i] = data.iloc[:,i].astype(str).str.replace(',', '')
    data.iloc[:,i] = data.iloc[:,i].astype(str).str.replace('-', '0')
data.head(9)
# Out:
#            관광지 유_무료 내국인_외국인    연도      1월      2월      3월     4월      5월  \
# 0   국립두타산자연휴양림   유료     내국인  2010    2831    1497     770    894    2600
# 1   국립평창청소년수련원   유료     내국인  2010    3325    3223   13914  21000   18763
# 2     대관령 양떼목장   유료     내국인  2010   29447   15370    5511  27198   65699
# 3        무이예술관   유료     내국인  2010     428     449     338    786    1887
# 4      삼양대관령목장   유료     내국인  2010   21170   12984    5660  25293   65600
# 5          선자령   유료     내국인  2010       0   21697    8788   1341    3195
# 6     신세계대관령콘도   유료     내국인  2010     480     984     390    250     520
# 7      알펜시아리조트   유료     내국인  2010   39383   38660    9193   7659    8416
# 8  용평 리조트 숙박시설   유료     내국인  2010  485941  324807  161382  97880  144485
#
#        6월      7월      8월      9월     10월     11월     12월     데이터기준일자
# 0    2763    6024    8578    3128    3383    1595    1920  2022-01-05
# 1   20125   18442   17518   11938   21221   10471    9354  2022-01-05
# 2   33472   48096   69116   28349   49100   24085    1929  2022-01-05
# 3     789    2512    5095    2435    1123     603     376  2022-01-05
# 4   31417   51794   86598   33614   57036   22101    1677  2022-01-05
# 5    1599    1620    1651    1628     257     577    2725  2022-01-05
# 6     395     480    1148     170     678     348     972  2022-01-05
# 7    8680   40892   86747   17154   36526   11619   48588  2022-01-05
# 8  124404  127863  176397  124200  143243  170450  429989  2022-01-05

# %%
data.iloc[:,3:16] = data.iloc[:,3:16].apply(pd.to_numeric)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   관광지      574 non-null    object
#  1   유_무료     574 non-null    object
#  2   내국인_외국인  574 non-null    object
#  3   연도       574 non-null    int64
#  4   1월       574 non-null    int64
#  5   2월       574 non-null    int64
#  6   3월       574 non-null    int64
#  7   4월       574 non-null    int64
#  8   5월       574 non-null    int64
#  9   6월       574 non-null    int64
#  10  7월       574 non-null    int64
#  11  8월       574 non-null    int64
#  12  9월       574 non-null    int64
#  13  10월      574 non-null    int64
#  14  11월      574 non-null    int64
#  15  12월      574 non-null    int64
#  16  데이터기준일자  574 non-null    object
# dtypes: int64(13), object(4)
# memory usage: 76.4+ KB

# %%
df = data.iloc[:,:-1]
df.head(10)
# Out:
#            관광지 유_무료 내국인_외국인    연도      1월      2월      3월     4월      5월  \
# 0   국립두타산자연휴양림   유료     내국인  2010    2831    1497     770    894    2600
# 1   국립평창청소년수련원   유료     내국인  2010    3325    3223   13914  21000   18763
# 2     대관령 양떼목장   유료     내국인  2010   29447   15370    5511  27198   65699
# 3        무이예술관   유료     내국인  2010     428     449     338    786    1887
# 4      삼양대관령목장   유료     내국인  2010   21170   12984    5660  25293   65600
# 5          선자령   유료     내국인  2010       0   21697    8788   1341    3195
# 6     신세계대관령콘도   유료     내국인  2010     480     984     390    250     520
# 7      알펜시아리조트   유료     내국인  2010   39383   38660    9193   7659    8416
# 8  용평 리조트 숙박시설   유료     내국인  2010  485941  324807  161382  97880  144485
# 9  용평리조트 유스호스텔   유료     내국인  2010    6132    2448     792    878    1902
#
#        6월      7월      8월      9월     10월     11월     12월
# 0    2763    6024    8578    3128    3383    1595    1920
# 1   20125   18442   17518   11938   21221   10471    9354
# 2   33472   48096   69116   28349   49100   24085    1929
# 3     789    2512    5095    2435    1123     603     376
# 4   31417   51794   86598   33614   57036   22101    1677
# 5    1599    1620    1651    1628     257     577    2725
# 6     395     480    1148     170     678     348     972
# 7    8680   40892   86747   17154   36526   11619   48588
# 8  124404  127863  176397  124200  143243  170450  429989
# 9     330     473       0       0       0    1064    2451

# %%
df["평균"] = df.iloc[:,4:16].mean(axis=1)
df['봄'] = df.iloc[:,6:9].sum(axis=1)
df['여름'] = df.iloc[:,9:12].sum(axis=1)
df['가을'] = df.iloc[:,12:15].sum(axis=1)
df['겨울'] = df.iloc[:,[15, 4, 5]].sum(axis=1)
df.head()
# Out:
#           관광지 유_무료 내국인_외국인    연도     1월     2월     3월     4월     5월     6월  \
# 0  국립두타산자연휴양림   유료     내국인  2010   2831   1497    770    894   2600   2763
# 1  국립평창청소년수련원   유료     내국인  2010   3325   3223  13914  21000  18763  20125
# 2    대관령 양떼목장   유료     내국인  2010  29447  15370   5511  27198  65699  33472
# 3       무이예술관   유료     내국인  2010    428    449    338    786   1887    789
# 4     삼양대관령목장   유료     내국인  2010  21170  12984   5660  25293  65600  31417
#
#    ...     8월     9월    10월    11월   12월            평균      봄      여름      가을  \
# 0  ...   8578   3128   3383   1595  1920   2998.583333   4264   17365    8106
# 1  ...  17518  11938  21221  10471  9354  14107.833333  53677   56085   43630
# 2  ...  69116  28349  49100  24085  1929  33114.333333  98408  150684  101534
# 3  ...   5095   2435   1123    603   376   1401.750000   3011    8396    4161
# 4  ...  86598  33614  57036  22101  1677  34578.666667  96553  169809  112751
#
#       겨울
# 0   6248
# 1  15902
# 2  46746
# 3   1253
# 4  35831
#
# [5 rows x 21 columns]

# %%
#먼저 내국인 데이터 외국인 데이터 나누기. 
local = df[df.iloc[:,2] == '내국인']
foreigner = df[df.iloc[:,2] == '외국인']

print(local.head())
print(foreigner.head())
# Out:
#           관광지 유_무료 내국인_외국인    연도     1월     2월     3월     4월     5월     6월  \
# 0  국립두타산자연휴양림   유료     내국인  2010   2831   1497    770    894   2600   2763
# 1  국립평창청소년수련원   유료     내국인  2010   3325   3223  13914  21000  18763  20125
# 2    대관령 양떼목장   유료     내국인  2010  29447  15370   5511  27198  65699  33472
# 3       무이예술관   유료     내국인  2010    428    449    338    786   1887    789
# 4     삼양대관령목장   유료     내국인  2010  21170  12984   5660  25293  65600  31417
#
#    ...     8월     9월    10월    11월   12월            평균      봄      여름      가을  \
# 0  ...   8578   3128   3383   1595  1920   2998.583333   4264   17365    8106
# 1  ...  17518  11938  21221  10471  9354  14107.833333  53677   56085   43630
# 2  ...  69116  28349  49100  24085  1929  33114.333333  98408  150684  101534
# 3  ...   5095   2435   1123    603   376   1401.750000   3011    8396    4161
# 4  ...  86598  33614  57036  22101  1677  34578.666667  96553  169809  112751
#
#       겨울
# 0   6248
# 1  15902
# 2  46746
# 3   1253
# 4  35831
#
# [5 rows x 21 columns]
#                     관광지 유_무료 내국인_외국인    연도     1월     2월    3월    4월    5월  \
# 21             대관령 양떼목장   유료     외국인  2010    449    186    80   415   790
# 22              알펜시아리조트   유료     외국인  2010  11337   3516  2369  2750  2000
# 23          용평 리조트 숙박시설   유료     외국인  2010  17953  16192  6845  3869  3210
# 24          용평리조트 유스호스텔   유료     외국인  2010    383    694     0     0     0
# 25  켄싱턴플로라호텔(이랜드레져비스평창)   유료     외국인  2010    424    272   176   382   441
#
#       6월  ...    8월    9월   10월   11월    12월           평균      봄     여름  \
# 21   407  ...   839   344   590   300     23   417.333333   1285   1831
# 22  2508  ...  4280   964  4976  3090  15033  4735.916667   7119  10796
# 23  3218  ...  3015  2958  5024  6414  18979  7524.833333  13924   8854
# 24     0  ...     0     0     0     0    600   139.750000      0      0
# 25   395  ...  1071   413   837   437    413   502.916667    999   2240
#
#        가을     겨울
# 21   1234    658
# 22   9030  29886
# 23  14396  53124
# 24      0   1677
# 25   1687   1109
#
# [5 rows x 21 columns]

# %%
local = local.reset_index(drop=True) #인덱스 초기화
foreigner = foreigner.reset_index(drop=True)
local
# Out:
#              관광지 유_무료 내국인_외국인    연도     1월     2월     3월     4월     5월     6월  \
# 0     국립두타산자연휴양림   유료     내국인  2010   2831   1497    770    894   2600   2763
# 1     국립평창청소년수련원   유료     내국인  2010   3325   3223  13914  21000  18763  20125
# 2       대관령 양떼목장   유료     내국인  2010  29447  15370   5511  27198  65699  33472
# 3          무이예술관   유료     내국인  2010    428    449    338    786   1887    789
# 4        삼양대관령목장   유료     내국인  2010  21170  12984   5660  25293  65600  31417
# ..           ...  ...     ...   ...    ...    ...    ...    ...    ...    ...
# 301  한화리조트(컨벤션홀)   유료     내국인  2021  19772  11964   7828  12344   8724  12476
# 302         허브나라   유료     내국인  2021    927   1222   1130   2999   6719   5811
# 303   휘닉스파크(골프장)   유료     내국인  2021      0      0      0  16280  21932  25291
# 304   휘닉스파크(스키장)   유료     내국인  2021  25450  34539    414  24890  43435  36424
# 305  휘닉스파크(워터파크)   유료     내국인  2021     40     16      0  15503  24374  23112
#
#      ...     8월     9월    10월    11월   12월            평균      봄      여름  \
# 0    ...   8578   3128   3383   1595  1920   2998.583333   4264   17365
# 1    ...  17518  11938  21221  10471  9354  14107.833333  53677   56085
# 2    ...  69116  28349  49100  24085  1929  33114.333333  98408  150684
# 3    ...   5095   2435   1123    603   376   1401.750000   3011    8396
# 4    ...  86598  33614  57036  22101  1677  34578.666667  96553  169809
# ..   ...    ...    ...    ...    ...   ...           ...    ...     ...
# 301  ...  24956  11308      0      0     0  11752.333333  28896   69088
# 302  ...   8633   5154      0      0     0   3189.500000  10848   20123
# 303  ...   8507   7350      0      0     0   7350.000000  38212   42638
# 304  ...  22977  17307      0      0     0  19031.416667  68739   82342
# 305  ...  30472  17221      0      0     0  11634.583333  39877   82461
#
#          가을     겨울
# 0      8106   6248
# 1     43630  15902
# 2    101534  46746
# 3      4161   1253
# 4    112751  35831
# ..      ...    ...
# 301   11308  31736
# 302    5154   2149
# 303    7350      0
# 304   17307  59989
# 305   17221     56
#
# [306 rows x 21 columns]

# %%
# 2010 년도 ~ 2021 년도 각 년도마다 총합 방문률이 가장 높은 수, 가장 작은 수 
def find_top_bottom(df):
    year_top = []
    year_bottom = []
    year = 2010
    top = 0
    bottom = 1000000000
    alls = 0
    for i in range(len(df)):
        alls = df.iloc[i, 16]
        if year == df.iloc[i, 3]:
            if alls > top:
                top = alls
            if alls < bottom:
                
                bottom = alls
        else:
            year += 1
            year_top.append(top)
            year_bottom.append(bottom)
            top = df.iloc[i, -1]
            bottom = df.iloc[i, -1]

    year_top.append(top)
    year_bottom.append(bottom)

    return year_top, year_bottom
    
local_top, local_bottom = find_top_bottom(local)
foreigner_top, foreigner_bottom = find_top_bottom(foreigner)

# %%
local_top

# %%
l_top = local['평균'][local['평균'].isin(local_top)].index
l_bottom =  local['평균'][local['평균'].isin(local_bottom)].index
f_top = foreigner['평균'][foreigner['평균'].isin(foreigner_top)].index
f_bottom = foreigner['평균'][foreigner['평균'].isin(foreigner_bottom)].index
l_top
# Out:
# Int64Index([8, 30, 51, 72, 100, 127, 154, 182, 210, 237, 264, 293], dtype='int64')

# %%
print(local['관광지'].value_counts(), "\n")
print(foreigner['관광지'].value_counts())
#용평리조트숙박시설 : 2010,2011,2012 년도 1위 
#오대산국립공원(월정사) : 2013년도 ~ 2020년도 1위
#용평리조트 발왕산 전망대 곤돌라 : 2021년도 1위
#2020년도 코로나 사태로 관광객 50% 급감 

# 용평리조트 숙박시설의 정보가 없음. 
# 용평리조트 골프, 곤돌라, 스키장 등 다른 부시설들의 합계가 늠.
# 따라서 2013년도부터 월정사가 총인원이 1순위가 됨
# Out:
# 국립평창청소년수련원             12
# 삼양대관령목장                12
# 국립두타산자연휴양림             12
# 무이예술관                  12
# 한국전통음식문화체험관            12
# 이효석문학관                 12
# 허브나라                   12
# 평창 동강민물고기생태관           11
# 평창힐링청소년수련원             11
# 호렙오대산청소년수련원            11
# 백룡동굴                   10
# 휘닉스파크(워터파크)             9
# 알펜시아리조트(스키장)            9
# 알펜시아리조트(오션700)          9
# 켄싱턴플로라호텔(컨벤션홀)          9
# 용평리조트(유스호스텔)            9
# 용평리조트(피크아일랜드)           9
# 용평리조트(발왕산전망대 곤돌라)       9
# 휘닉스파크(스키장)              9
# 용평리조트(골프장)              9
# 용평리조트(스키장)              9
# 대관령 양떼목장                9
# 오대산국립공원(월정사)            9
# 켄싱턴플로라호텔(글램핑)           9
# 알펜시아리조트(골프장)            9
# 한화리조트(컨벤션홀)             9
# 휘닉스파크(골프장)              9
# 용평 리조트 숙박시설             3
# 한국자생식물원                 3
# 알펜시아리조트                 3
# 한국앵무새학교                 3
# 휘닉스파크 숙박시설              3
# 선자령                     3
# 한화리조트                   3
# 켄싱턴플로라호텔(이랜드레져비스평창)     3
# 용평리조트 유스호스텔             3
# 휘닉스파크 유스호스텔             3
# 비엔나인형박물관                2
# 신세계대관령콘도                2
# 로하스파크(와카푸카)             1
# Name: 관광지, dtype: int64
#
# 한국전통음식문화체험관            12
# 허브나라                   12
# 한화리조트(컨벤션홀)             9
# 용평리조트(유스호스텔)            9
# 국립평창청소년수련원              9
# 용평리조트(발왕산전망대 곤돌라)       9
# 켄싱턴플로라호텔(컨벤션홀)          9
# 알펜시아리조트(스키장)            9
# 알펜시아리조트(오션700)          9
# 용평리조트(골프장)              9
# 대관령 양떼목장                9
# 휘닉스파크(워터파크)             9
# 켄싱턴플로라호텔(글램핑)           9
# 용평리조트(피크아일랜드)           9
# 휘닉스파크(스키장)              9
# 오대산국립공원(월정사)            9
# 용평리조트(스키장)              9
# 휘닉스파크(골프장)              9
# 삼양대관령목장                 9
# 무이예술관                   8
# 백룡동굴                    8
# 알펜시아리조트(골프장)            8
# 이효석문학관                  8
# 국립두타산자연휴양림              8
# 호렙오대산청소년수련원             7
# 평창힐링청소년수련원              7
# 평창 동강민물고기생태관            7
# 휘닉스파크 숙박시설              3
# 한화리조트                   3
# 알펜시아리조트                 3
# 한국자생식물원                 3
# 용평 리조트 숙박시설             3
# 켄싱턴플로라호텔(이랜드레져비스평창)     3
# 휘닉스파크 유스호스텔             3
# 용평리조트 유스호스텔             3
# 한국앵무새학교                 3
# 비엔나인형박물관                2
# 로하스파크(와카푸카)             1
# Name: 관광지, dtype: int64

# %%
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False
plt.figure(figsize=(20,8))
plt.title("연도별 내국인 최고 평균 방문 관광지 선정 빈도")
local.iloc[l_top, :]['관광지'].value_counts().plot.pie(autopct=lambda p : '{:.2f}%'.format(p))
#내국인의 경우 가는 곳이 한정적이다.
#또한 가지 않는 곳도 정해져 있다.
# Out:
# <AxesSubplot:title={'center':'연도별 내국인 최고 평균 방문 관광지 선정 빈도'}, ylabel='관광지'>

# %%
local.iloc[l_bottom, :]['관광지'].value_counts()
# Out:
# 호렙오대산청소년수련원      6
# 한국전통음식문화체험관      3
# 평창 동강민물고기생태관     3
# 한국앵무새학교          2
# 신세계대관령콘도         1
# 켄싱턴플로라호텔(글램핑)    1
# 평창힐링청소년수련원       1
# Name: 관광지, dtype: int64

# %%
plt.figure(figsize=(20,8))
plt.title("연도별 내국인 최저 평균 방문 관광지 선정 빈도")
local.iloc[l_bottom, :]['관광지'].value_counts().plot.pie(autopct=lambda p : '{:.2f}%'.format(p))
# Out:
# <AxesSubplot:title={'center':'연도별 내국인 최저 평균 방문 관광지 선정 빈도'}, ylabel='관광지'>

# %%
plt.figure(figsize=(20,8))
plt.subplot(121)
plt.title("내국인 최대 평균 방문 관광지의 관광객 수 변동 추이")
plt.plot(local.iloc[l_top, :]['연도'], local.iloc[l_top, :]['평균'])
plt.show()
#시간이 지날수록 줄어듬
#하지만 용평리조트의 숙박시설의 정보가 포함되었다면 달랐을 것 같다.

# %%
plt.figure(figsize=(20,8))
plt.title("내국인 최저 평균 방문 관광지의 관광객 수 변동 추이")
plt.plot(local.iloc[l_bottom, :]['연도'], local.iloc[l_bottom, :]['평균'])
plt.show()

# %%
plt.title("방문이 없는 관광지의 빈도 수")
local.iloc[l_bottom, :].iloc[6:, :]['관광지'].value_counts().plot.pie(autopct=lambda p : '{:.2f}%'.format(p))
local.iloc[l_bottom, :].iloc[6:, :]['관광지'].value_counts()
# Out:
# 호렙오대산청소년수련원     5
# 평창 동강민물고기생태관    2
# 한국앵무새학교         2
# 한국전통음식문화체험관     1
# 평창힐링청소년수련원      1
# Name: 관광지, dtype: int64

# %%
local.iloc[local['관광지'][local['관광지'].isin(local.iloc[l_top, :]['관광지'].unique())].index, [0,1,2,3,-5]]

# %%
local.info()

# %%
def sessons(df, sesson):
    top = 0
    bottom = 100000000
    year = 2010
    tops = []
    bottoms = []
    for i in range(len(df)):
        s = df.iloc[i, sesson]
        if year == df.iloc[i, 3]:
            if s > top :
                top = s
                
            if s < bottom:
                bottom = s
        else:
            year += 1
            tops.append(top)
            bottoms.append(bottom)
            top = s
            bottom = s
                
    tops.append(top)
    bottoms.append(bottom) 
        
    return tops, bottoms

l_spring_top, l_spring_bottom = sessons(local, 17)
l_summer_top, l_summer_bottom = sessons(local, 18)
l_autumn_top, l_autumn_bottom = sessons(local, 19)
l_winter_top, l_winter_bottom = sessons(local, 20)

# %%
local_spring_top = local['봄'][local['봄'].isin(l_spring_top)].index
local_spring_bottom =  local['봄'][local['봄'].isin(l_spring_bottom)].index
local_summer_top = local['여름'][local['여름'].isin(l_summer_top)].index
local_summer_bottom =  local['여름'][local['여름'].isin(l_summer_bottom)].index
local_actumn_top = local['가을'][local['가을'].isin(l_autumn_top)].index
local_actumn_bottom =  local['가을'][local['가을'].isin(l_autumn_bottom)].index
local_winter_top = local['겨울'][local['겨울'].isin(l_winter_top)].index
local_winter_bottom =  local['겨울'][local['겨울'].isin(l_winter_bottom)].index

# %%
plt.figure(figsize=(40,10))
plt.subplot(141)
plt.title("연도 별 봄 최고 방문 관광지 비율")
local.iloc[local_spring_top,:]['관광지'].value_counts().plot.pie(autopct=lambda p : '{:.2f}%'.format(p))
plt.subplot(142)
plt.title("연도 별 여름 최고 방문 관광지 비율")
local.iloc[local_summer_top,:]['관광지'].value_counts().plot.pie(autopct=lambda p : '{:.2f}%'.format(p))
plt.subplot(143)
plt.title("연도 별 가을 최고 방문 관광지 비율")
local.iloc[local_actumn_top,:]['관광지'].value_counts().plot.pie(autopct=lambda p : '{:.2f}%'.format(p))
plt.subplot(144)
plt.title("연도 별 겨울 최고 방문 관광지 비율")
local.iloc[local_winter_top,:]['관광지'].value_counts().plot.pie(autopct=lambda p : '{:.2f}%'.format(p))
# Out:
# <AxesSubplot:title={'center':'연도 별 겨울 최고 방문 관광지 비율'}, ylabel='관광지'>

# %%
plt.figure(figsize=(40,10))
plt.subplot(141)
plt.title("년도 별 봄 최저 방문 관광지 비율")
local.iloc[local_spring_bottom,:]['관광지'].value_counts().plot.pie(autopct=lambda p : '{:.2f}%'.format(p))
plt.subplot(142)
plt.title("년도 별 여름 최저 방문 관광지 비율")
local.iloc[local_summer_bottom,:]['관광지'].value_counts().plot.pie(autopct=lambda p : '{:.2f}%'.format(p))
plt.subplot(143)
plt.title("년도 별 가을 최저 방문 관광지 비율")
local.iloc[local_actumn_bottom,:]['관광지'].value_counts().plot.pie(autopct=lambda p : '{:.2f}%'.format(p))
plt.subplot(144)
plt.title("년도 별 겨울 최저 방문 관광지 비율")
local.iloc[local_winter_bottom,:]['관광지'].value_counts().plot.pie(autopct=lambda p : '{:.2f}%'.format(p))
# Out:
# <AxesSubplot:title={'center':'년도 별 겨울 최저 방문 관광지 비율'}, ylabel='관광지'>

# %%
plt.figure(figsize=(20,8))
plt.title("외국인 각 연도별 최대 방문 관광지 선정 빈도")
local.iloc[f_top, :]['관광지'].value_counts().plot.pie(autopct=lambda p : '{:.2f}%'.format(p))

#월정사와 휘닉스파크, 용평리조트의 경우 겹치는 부분이 있다.
#하지만 내국인에서 최저를 보였던 한국전통음식문화체험관의 경우 외국인들이 가장 많은 방문 관광지로 됐었던 적이 있다.
#외국인의 경우 다양한
# Out:
# <AxesSubplot:title={'center':'외국인 각 연도별 최대 방문 관광지 선정 빈도'}, ylabel='관광지'>

# %%
plt.figure(figsize=(20,8))
plt.title("외국인 각 연도별 최저 방문 관광지 선정 빈도")
local.iloc[f_bottom, :]['관광지'].value_counts().plot.pie(autopct=lambda p : '{:.2f}%'.format(p))
# Out:
# <AxesSubplot:title={'center':'외국인 각 연도별 최저 방문 관광지 선정 빈도'}, ylabel='관광지'>
